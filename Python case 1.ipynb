# %%
import numpy as np
import pandas as pd

# %%
customer = pd.read_csv("C:/Users/shubh dwivedi/Downloads/Python Foundation Case Study 1 - Retail Case Study/Customer.csv")
customer
# Out:
#       customer_Id         DOB Gender  city_code
# 0          268408  02-01-1970      M        4.0
# 1          269696  07-01-1970      F        8.0
# 2          268159  08-01-1970      F        8.0
# 3          270181  10-01-1970      F        2.0
# 4          268073  11-01-1970      M        1.0
# ...           ...         ...    ...        ...
# 5642       274474  19-12-1992      M        2.0
# 5643       267666  24-12-1992      M        6.0
# 5644       270476  25-12-1992      F        3.0
# 5645       269626  27-12-1992      F        5.0
# 5646       274308  29-12-1992      F        5.0
#
# [5647 rows x 4 columns]

# %%
transactions = pd.read_csv("C:/Users/shubh dwivedi/Downloads/Python Foundation Case Study 1 - Retail Case Study/Transactions.csv")
transactions
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# ...

# %%
prod_cat = pd.read_csv("C:/Users/shubh dwivedi/Downloads/Python Foundation Case Study 1 - Retail Case Study/prod_cat_info.csv")
prod_cat
# Out:
#     prod_cat_code          prod_cat  prod_sub_cat_code          prod_subcat
# 0               1          Clothing                  4                 Mens
# 1               1          Clothing                  1                Women
# 2               1          Clothing                  3                 Kids
# 3               2          Footwear                  1                 Mens
# 4               2          Footwear                  3                Women
# 5               2          Footwear                  4                 Kids
# 6               3       Electronics                  4              Mobiles
# 7               3       Electronics                  5            Computers
# 8               3       Electronics                  8  Personal Appliances
# 9               3       Electronics                  9              Cameras
# 10              3       Electronics                 10      Audio and video
# ...

# %%
prod_cat = prod_cat.rename(columns= {"prod_sub_cat_code":"prod_subcat_code"})
prod_cat
# Out:
#     prod_cat_code          prod_cat  prod_subcat_code          prod_subcat
# 0               1          Clothing                 4                 Mens
# 1               1          Clothing                 1                Women
# 2               1          Clothing                 3                 Kids
# 3               2          Footwear                 1                 Mens
# 4               2          Footwear                 3                Women
# 5               2          Footwear                 4                 Kids
# 6               3       Electronics                 4              Mobiles
# 7               3       Electronics                 5            Computers
# 8               3       Electronics                 8  Personal Appliances
# 9               3       Electronics                 9              Cameras
# 10              3       Electronics                10      Audio and video
# ...

# %% [markdown]
# #### ques 1 - merge all the tables

# %%
customer_det = pd.merge(left=customer,right=transactions,left_on='customer_Id',right_on='cust_id',how='inner')
customer_det
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 0           268408  02-01-1970      M        4.0     87243835584   268408
# 1           268408  02-01-1970      M        4.0     16197868036   268408
# 2           268408  02-01-1970      M        4.0     16197868036   268408
# 3           268408  02-01-1970      M        4.0     28810141075   268408
# 4           268408  02-01-1970      M        4.0     64633435931   268408
# ...            ...         ...    ...        ...             ...      ...
# 23048       269626  27-12-1992      F        5.0     71369029396   269626
# 23049       269626  27-12-1992      F        5.0     94134051896   269626
# 23050       274308  29-12-1992      F        5.0     26208690928   274308
# 23051       274308  29-12-1992      F        5.0     57358822237   274308
# 23052       274308  29-12-1992      F        5.0     58160544337   274308
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# ...

# %%
customer_Final=customer_det.merge(prod_cat,how="inner",left_on=["prod_cat_code","prod_subcat_code"],
                                        right_on=["prod_cat_code","prod_subcat_code"])

# %%
customer_Final
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 0           268408  02-01-1970      M        4.0     87243835584   268408
# 1           275152  16-01-1970      M        4.0     73109425404   275152
# 2           275034  18-01-1970      F        4.0     64777271023   275034
# 3           270829  22-01-1970      F        8.0     87174343938   270829
# 4           267657  29-01-1970      F        7.0     76242744953   267657
# ...            ...         ...    ...        ...             ...      ...
# 23048       267812  04-12-1992      F        1.0     63540378797   267812
# 23049       274618  09-12-1992      F        7.0     71793203305   274618
# 23050       268097  15-12-1992      F        7.0     91217108818   268097
# 23051       268097  15-12-1992      F        7.0     90114483354   268097
# 23052       268097  15-12-1992      F        7.0     90114483354   268097
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# ...

# %% [markdown]
# #### ques 2
# ##### A) column name and corresponding datatypes

# %%
customer_Final.dtypes
# Out:
# customer_Id           int64
# DOB                  object
# Gender               object
# city_code           float64
# transaction_id        int64
# cust_id               int64
# tran_date            object
# prod_subcat_code      int64
# prod_cat_code         int64
# Qty                   int64
# Rate                  int64
# Tax                 float64
# total_amt           float64
# Store_type           object
# prod_cat             object
# prod_subcat          object
# dtype: object

# %%
customer_Final['DOB'] = customer_Final['DOB'].apply(lambda x :pd.to_datetime(x))
customer_Final['tran_date'] = customer_Final['tran_date'].apply(lambda x :pd.to_datetime(x))

# %%
customer_Final.dtypes
# Out:
# customer_Id                  int64
# DOB                 datetime64[ns]
# Gender                      object
# city_code                  float64
# transaction_id               int64
# cust_id                      int64
# tran_date           datetime64[ns]
# prod_subcat_code             int64
# prod_cat_code                int64
# Qty                          int64
# Rate                         int64
# Tax                        float64
# total_amt                  float64
# Store_type                  object
# prod_cat                    object
# prod_subcat                 object
# dtype: object

# %%
customer_Final.isnull().sum()
# Out:
# customer_Id         0
# DOB                 0
# Gender              9
# city_code           8
# transaction_id      0
# cust_id             0
# tran_date           0
# prod_subcat_code    0
# prod_cat_code       0
# Qty                 0
# Rate                0
# Tax                 0
# total_amt           0
# Store_type          0
# prod_cat            0
# prod_subcat         0
# dtype: int64

# %%
customer_Final.duplicated().sum()
# Out:
# 13

# %%
customer_Final.drop_duplicates(inplace=True)

# %%
customer_Final.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### B) Top/Bottom 10 observation

# %%
customer_final.head(10)
# Out:
#    customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 0       268408  02-01-1970      M        4.0     87243835584   268408
# 1       275152  16-01-1970      M        4.0     73109425404   275152
# 2       275034  18-01-1970      F        4.0     64777271023   275034
# 3       270829  22-01-1970      F        8.0     87174343938   270829
# 4       267657  29-01-1970      F        7.0     76242744953   267657
# 5       274630  01-02-1970      M        4.0     78357345891   274630
# 6       273541  01-02-1970      M        4.0     23916816961   273541
# 7       269008  13-02-1970      F        6.0     35560569829   269008
# 8       269008  13-02-1970      F        6.0     94033312891   269008
# 9       267199  14-02-1970    NaN        2.0     56749259881   267199
#
#     tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  total_amt  \
# 0  13-01-2014                 7              5    5   187   98.175   1033.175
# ...

# %%
customer_final.tail(10)
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 23043       268914  15-11-1992      F        3.0      1407823655   268914
# 23044       269519  17-11-1992      M        9.0     29719500605   269519
# 23045       273524  25-11-1992      F        1.0     25762805863   273524
# 23046       272141  02-12-1992      F       10.0     71337087467   272141
# 23047       272141  02-12-1992      F       10.0     71337087467   272141
# 23048       267812  04-12-1992      F        1.0     63540378797   267812
# 23049       274618  09-12-1992      F        7.0     71793203305   274618
# 23050       268097  15-12-1992      F        7.0     91217108818   268097
# 23051       268097  15-12-1992      F        7.0     90114483354   268097
# 23052       268097  15-12-1992      F        7.0     90114483354   268097
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# 23043   10/6/2011                10              5    1  1252  131.460
# ...

# %% [markdown]
# ##### C) five point summary

# %%
customer_final['total_amt'].describe()
# Out:
# count    23053.000000
# mean      2107.308002
# std       2507.561264
# min      -8270.925000
# 25%        762.450000
# 50%       1754.740000
# 75%       3569.150000
# max       8287.500000
# Name: total_amt, dtype: float64

# %% [markdown]
# ##### D) frequency tables for all categorical tables

# %%
customer_final.loc[:,customer_final.dtypes=="object"].describe()
# Out:
#                DOB Gender   tran_date Store_type prod_cat prod_subcat
# count        23053  23044       23053      23053    23053       23053
# unique        3987      2        1129          4        6          18
# top     27-12-1988      M  13-07-2011     e-Shop    Books       Women
# freq            32  11811          35       9311     6069        3048

# %% [markdown]
# #### Ques 3 Histograms for all continuous variables and frequency for categorical variables

# %%
import matplotlib.pyplot as plt

# %%
#Q3 for continuous variable
#Tax
import matplotlib.pyplot as plt
Tax = customer_final['Tax']
plt.hist(Tax,color=['green'])
plt.xlabel('tax')
plt.ylabel('frequency')
plt.show()

# %%
#Q3
#for totalamount
Total_Amount=customer_final["total_amt"]
plt.hist(Total_Amount,color="red")
plt.xlabel("total amount")
plt.ylabel("frequency")
plt.show()

# %%
#Q3 for categorical variable
#for gender
customer_final['Gender'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#for prod_code
customer_final['prod_cat'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#for prod_subcat
customer_final['prod_subcat'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#forStore_type
customer_final['Store_type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### 4. Calculate the following information using the merged dataset :
# ##### a. Time period of the available transaction data

# %%
min_date = customer_Final['tran_date'].min()
min_date
# Out:
# Timestamp('2011-01-02 00:00:00')

# %%
max_date = customer_Final['tran_date'].max()
max_date
# Out:
# Timestamp('2014-12-02 00:00:00')

# %%
print("Time period of the available transaction data is from " + pd.Timestamp.strftime(min_date,format="%d-%m-%y") + " to " 
     + pd.Timestamp.strftime(max_date,format="%d-%m-%y"))
# Out:
# Time period of the available transaction data is from 02-01-11 to 02-12-14

# %% [markdown]
# #### 4) b. Count of transactions where the total amount of transaction was negative

# %%
tran_negative = customer_Final[customer_Final['total_amt']<0].count()
tran_negative
# Out:
# customer_Id         2164
# DOB                 2164
# Gender              2163
# city_code           2164
# transaction_id      2164
# cust_id             2164
# tran_date           2164
# prod_subcat_code    2164
# prod_cat_code       2164
# Qty                 2164
# Rate                2164
# Tax                 2164
# total_amt           2164
# Store_type          2164
# prod_cat            2164
# prod_subcat         2164
# dtype: int64

# %% [markdown]
# #### Q5. Analyze which product categories are more popular among females vs male customers.

# %%
customer_Final.groupby(['prod_cat','Gender'])[['Qty']].count().sort_values(by='Qty',ascending = False)
# Out:
#                           Qty
# prod_cat         Gender
# Books            M       3116
#                  F       2946
# Electronics      M       2567
#                  F       2328
# Home and kitchen M       2132
#                  F       1993
# Footwear         F       1528
# Clothing         M       1518
# Footwear         M       1467
# Clothing         F       1439
# Bags             M       1004
#                  F        993

# %% [markdown]
# #### Q6. Which City code has the maximum customers and what was the percentage of customers from that city?

# %%
#Q6
c1=customer_final['city_code'].value_counts()
c1
# Out:
# 4.0     2422
# 3.0     2411
# 5.0     2360
# 7.0     2356
# 10.0    2333
# 8.0     2330
# 2.0     2270
# 1.0     2258
# 9.0     2178
# 6.0     2127
# Name: city_code, dtype: int64

# %%
c2=customer_final['city_code'].count()
c2
# Out:
# 23045

# %%
c3 = (c1/c2)*100
c3
# Out:
# 4.0     10.509872
# 3.0     10.462139
# 5.0     10.240833
# 7.0     10.223476
# 10.0    10.123671
# 8.0     10.110653
# 2.0      9.850293
# 1.0      9.798221
# 9.0      9.451074
# 6.0      9.229768
# Name: city_code, dtype: float64

# %%
customer_final['Store_type'].value_counts()
# Out:
# e-Shop            9311
# MBR               4661
# Flagship store    4577
# TeleShop          4504
# Name: Store_type, dtype: int64

# %% [markdown]
# #### Q7. Which store type sells the maximum products by value and by quantity?

# %%
customer_final.sort_values(['Rate','Qty'],ascending=False).head(1)['Store_type']
# Out:
# 3184    e-Shop
# Name: Store_type, dtype: object

# %% [markdown]
# #### Q8. What was the total amount earned from the "Electronics" and "Clothing" categories from Flagship Stores?

# %%
customer_amount1=customer_final[(customer_final['Store_type']== 'Flagship store') &
                                ((customer_final['prod_cat']=='Electronics') |
                                (customer_final['prod_cat']=='Clothing'))]['total_amt'].sum()
customer_amount1
# Out:
# 3409559.27

# %% [markdown]
# #### Q9. What was the total amount earned from "Male" customers under the "Electronics" category?

# %%
customer_amount=customer_final[(customer_final['Gender']== 'M') & (customer_final['prod_cat']=='Electronics')]['total_amt'].sum()
customer_amount
# Out:
# 5703109.425

# %% [markdown]
# #### Q10. How many customers have more than 10 unique transactions, after removing all transactions which have any negative amounts?

# %%
postive_amt=customer_final.loc[customer_final['total_amt']>0]
postive_amt
# Out:
#        customer_Id         DOB Gender  city_code  transaction_id  cust_id  \
# 0           268408  02-01-1970      M        4.0     87243835584   268408
# 1           275152  16-01-1970      M        4.0     73109425404   275152
# 2           275034  18-01-1970      F        4.0     64777271023   275034
# 3           270829  22-01-1970      F        8.0     87174343938   270829
# 4           267657  29-01-1970      F        7.0     76242744953   267657
# ...            ...         ...    ...        ...             ...      ...
# 23047       272141  02-12-1992      F       10.0     71337087467   272141
# 23048       267812  04-12-1992      F        1.0     63540378797   267812
# 23049       274618  09-12-1992      F        7.0     71793203305   274618
# 23050       268097  15-12-1992      F        7.0     91217108818   268097
# 23052       268097  15-12-1992      F        7.0     90114483354   268097
#
#         tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# ...

# %%
unique_trans = postive_amt.groupby(['customer_Id','prod_cat','prod_subcat'])['transaction_id'].count().reset_index()
unique_trans
# Out:
#        customer_Id          prod_cat  prod_subcat  transaction_id
# 0           266783             Books  Non-Fiction               1
# 1           266783          Clothing         Mens               2
# 2           266783          Footwear         Mens               1
# 3           266784             Books      Fiction               1
# 4           266784             Books  Non-Fiction               1
# ...            ...               ...          ...             ...
# 19273       275264             Books  Non-Fiction               1
# 19274       275264  Home and kitchen        Tools               1
# 19275       275265              Bags         Mens               1
# 19276       275265             Books     Academic               1
# 19277       275265  Home and kitchen   Furnishing               1
#
# [19278 rows x 4 columns]

# %%
unique_transaction = unique_trans.groupby('customer_Id')[['transaction_id']].count().sort_values(by='transaction_id',ascending=False)
unique_transaction
# Out:
#              transaction_id
# customer_Id
# 270908                   10
# 272286                   10
# 274854                   10
# 273014                   10
# 268076                    9
# ...                     ...
# 270259                    1
# 270265                    1
# 267996                    1
# 272656                    1
# 269114                    1
#
# [5506 rows x 1 columns]

# %%
unique_transaction[unique_transaction["transaction_id"]>10]
# Out:
# Empty DataFrame
# Columns: [transaction_id]
# Index: []

# %% [markdown]
# #### Ques 11  For all customers aged between 25 - 35, find out:

# %%
curr_year=pd.to_datetime('today').year
curr_year
# Out:
# 2023

# %%
customer_Final["DOB_year"]=customer_Final["DOB"].dt.year
customer_Final
# Out:
#        customer_Id        DOB Gender  city_code  transaction_id  cust_id  \
# 0           268408 1970-02-01      M        4.0     87243835584   268408
# 1           275152 1970-01-16      M        4.0     73109425404   275152
# 2           275034 1970-01-18      F        4.0     64777271023   275034
# 3           270829 1970-01-22      F        8.0     87174343938   270829
# 4           267657 1970-01-29      F        7.0     76242744953   267657
# ...            ...        ...    ...        ...             ...      ...
# 23048       267812 1992-04-12      F        1.0     63540378797   267812
# 23049       274618 1992-09-12      F        7.0     71793203305   274618
# 23050       268097 1992-12-15      F        7.0     91217108818   268097
# 23051       268097 1992-12-15      F        7.0     90114483354   268097
# 23052       268097 1992-12-15      F        7.0     90114483354   268097
#
#        tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# ...

# %%
customer_Final["age"]=curr_year - customer_Final["DOB_year"]

# %%
customer_Final
# Out:
#        customer_Id        DOB Gender  city_code  transaction_id  cust_id  \
# 0           268408 1970-02-01      M        4.0     87243835584   268408
# 1           275152 1970-01-16      M        4.0     73109425404   275152
# 2           275034 1970-01-18      F        4.0     64777271023   275034
# 3           270829 1970-01-22      F        8.0     87174343938   270829
# 4           267657 1970-01-29      F        7.0     76242744953   267657
# ...            ...        ...    ...        ...             ...      ...
# 23048       267812 1992-04-12      F        1.0     63540378797   267812
# 23049       274618 1992-09-12      F        7.0     71793203305   274618
# 23050       268097 1992-12-15      F        7.0     91217108818   268097
# 23051       268097 1992-12-15      F        7.0     90114483354   268097
# 23052       268097 1992-12-15      F        7.0     90114483354   268097
#
#        tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# ...

# %% [markdown]
# #### a. What was the total amount spent for “Electronics” and “Books” product categories?

# %%
total_amt_spend=customer_Final[((customer_Final['prod_cat']=='Electronics') | 
                                (customer_Final['prod_cat']=='Books')) & 
                               (customer_Final['age']>=25) & (customer_Final['age']<=35)]['total_amt'].sum()

# %%
total_amt_spend
# Out:
# 4940387.595

# %% [markdown]
# #### b. What was the total amount spent by these customers between 1st Jan, 2014 to 1st Mar, 2014?

# %%
age_25_35_customer=customer_Final[(customer_Final['age']>=25) & (customer_Final['age']<=35)] 
age_25_35_customer
# Out:
#        customer_Id        DOB Gender  city_code  transaction_id  cust_id  \
# 823         270463 1988-06-01      M        9.0     56287350550   270463
# 824         270388 1988-01-22      M        9.0     73882970999   270388
# 825         273785 1988-01-22      M        5.0     79369372618   273785
# 826         268773 1988-08-02      M        1.0     68033148936   268773
# 827         270096 1988-02-28      M       10.0     83330815681   270096
# ...            ...        ...    ...        ...             ...      ...
# 23048       267812 1992-04-12      F        1.0     63540378797   267812
# 23049       274618 1992-09-12      F        7.0     71793203305   274618
# 23050       268097 1992-12-15      F        7.0     91217108818   268097
# 23051       268097 1992-12-15      F        7.0     90114483354   268097
# 23052       268097 1992-12-15      F        7.0     90114483354   268097
#
#        tran_date  prod_subcat_code  prod_cat_code  Qty  Rate      Tax  \
# ...

# %%
t_date = age_25_35_customer[(age_25_35_customer['tran_date'] > '2014-01-01') & (age_25_35_customer['tran_date'] < '2014-03-01')]
total_amount = t_date.total_amt.sum()
print('Total amount spent by the customer - ',total_amount)
# Out:
# Total amount spent by the customer -  340788.63
